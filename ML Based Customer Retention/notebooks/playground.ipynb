# %%
import pandas as pd

# %%
df = pd.read_excel('E_Commerce_Dataset.xlsx', sheet_name='E Comm')

# %%
df
# Out:
#       CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  \
# 0          50001      1     4.0         Mobile Phone         3
# 1          50002      1     NaN                Phone         1
# 2          50003      1     NaN                Phone         1
# 3          50004      1     0.0                Phone         3
# 4          50005      1     0.0                Phone         1
# ...          ...    ...     ...                  ...       ...
# 5625       55626      0    10.0             Computer         1
# 5626       55627      0    13.0         Mobile Phone         1
# 5627       55628      0     1.0         Mobile Phone         1
# 5628       55629      0    23.0             Computer         3
# 5629       55630      0     8.0         Mobile Phone         1
#
#       WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 0                 6.0           Debit Card  Female             3.0
# 1                 8.0                  UPI    Male             3.0
# 2                30.0           Debit Card    Male             2.0
# 3                15.0           Debit Card    Male             2.0
# 4                12.0                   CC    Male             NaN
# ...               ...                  ...     ...             ...
# 5625             30.0          Credit Card    Male             3.0
# 5626             13.0          Credit Card    Male             3.0
# 5627             11.0           Debit Card    Male             3.0
# 5628              9.0          Credit Card    Male             4.0
# 5629             15.0          Credit Card    Male             3.0
#
#       NumberOfDeviceRegistered    PreferedOrderCat  SatisfactionScore  \
# 0                            3  Laptop & Accessory                  2
# 1                            4              Mobile                  3
# 2                            4              Mobile                  3
# 3                            4  Laptop & Accessory                  5
# 4                            3              Mobile                  5
# ...                        ...                 ...                ...
# 5625                         2  Laptop & Accessory                  1
# 5626                         5             Fashion                  5
# 5627                         2  Laptop & Accessory                  4
# 5628                         5  Laptop & Accessory                  4
# 5629                         2  Laptop & Accessory                  3
#
#      MaritalStatus  NumberOfAddress  Complain  OrderAmountHikeFromlastYear  \
# 0           Single                9         1                         11.0
# 1           Single                7         1                         15.0
# 2           Single                6         1                         14.0
# 3           Single                8         0                         23.0
# 4           Single                3         0                         11.0
# ...            ...              ...       ...                          ...
# 5625       Married                6         0                         18.0
# 5626       Married                6         0                         16.0
# 5627       Married                3         1                         21.0
# 5628       Married                4         0                         15.0
# 5629       Married                4         0                         13.0
#
#       CouponUsed  OrderCount  DaySinceLastOrder  CashbackAmount
# 0            1.0         1.0                5.0          159.93
# 1            0.0         1.0                0.0          120.90
# 2            0.0         1.0                3.0          120.28
# 3            0.0         1.0                3.0          134.07
# 4            1.0         1.0                3.0          129.60
# ...          ...         ...                ...             ...
# 5625         1.0         2.0                4.0          150.71
# 5626         1.0         2.0                NaN          224.91
# 5627         1.0         2.0                4.0          186.42
# 5628         2.0         2.0                9.0          178.90
# 5629         2.0         2.0                3.0          169.04
#
# [5630 rows x 20 columns]

# %%
df.drop(columns=['CustomerID'], inplace=True)

# %%
df.isnull().sum()
# Out:
# Churn                            0
# Tenure                         264
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# SatisfactionScore                0
# MaritalStatus                    0
# NumberOfAddress                  0
# Complain                         0
# OrderAmountHikeFromlastYear    265
# CouponUsed                     256
# OrderCount                     258
# DaySinceLastOrder              307
# CashbackAmount                   0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0         1     4.0         Mobile Phone         3              6.0
# 3         1     0.0                Phone         3             15.0
# 5         1     0.0             Computer         1             22.0
# 11        1    11.0         Mobile Phone         1              6.0
# 12        1     0.0                Phone         1             11.0
# ...     ...     ...                  ...       ...              ...
# 5624      0     1.0         Mobile Phone         3             12.0
# 5625      0    10.0             Computer         1             30.0
# 5627      0     1.0         Mobile Phone         1             11.0
# 5628      0    23.0             Computer         3              9.0
# 5629      0     8.0         Mobile Phone         1             15.0
#
#      PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0              Debit Card  Female             3.0                         3
# 3              Debit Card    Male             2.0                         4
# 5              Debit Card  Female             3.0                         5
# 11             Debit Card    Male             3.0                         4
# 12                    COD    Male             2.0                         3
# ...                   ...     ...             ...                       ...
# 5624                  UPI  Female             2.0                         5
# 5625          Credit Card    Male             3.0                         2
# 5627           Debit Card    Male             3.0                         2
# 5628          Credit Card    Male             4.0                         5
# 5629          Credit Card    Male             3.0                         2
#
#         PreferedOrderCat  SatisfactionScore MaritalStatus  NumberOfAddress  \
# 0     Laptop & Accessory                  2        Single                9
# 3     Laptop & Accessory                  5        Single                8
# 5           Mobile Phone                  5        Single                2
# 11               Fashion                  3        Single               10
# 12                Mobile                  3        Single                2
# ...                  ...                ...           ...              ...
# 5624        Mobile Phone                  3        Single                2
# 5625  Laptop & Accessory                  1       Married                6
# 5627  Laptop & Accessory                  4       Married                3
# 5628  Laptop & Accessory                  4       Married                4
# 5629  Laptop & Accessory                  3       Married                4
#
#       Complain  OrderAmountHikeFromlastYear  CouponUsed  OrderCount  \
# 0            1                         11.0         1.0         1.0
# 3            0                         23.0         0.0         1.0
# 5            1                         22.0         4.0         6.0
# 11           1                         13.0         0.0         1.0
# 12           1                         13.0         2.0         2.0
# ...        ...                          ...         ...         ...
# 5624         0                         19.0         2.0         2.0
# 5625         0                         18.0         1.0         2.0
# 5627         1                         21.0         1.0         2.0
# 5628         0                         15.0         2.0         2.0
# 5629         0                         13.0         2.0         2.0
#
#       DaySinceLastOrder  CashbackAmount
# 0                   5.0          159.93
# 3                   3.0          134.07
# 5                   7.0          139.19
# 11                  0.0          153.81
# 12                  2.0          134.41
# ...                 ...             ...
# 5624                1.0          154.66
# 5625                4.0          150.71
# 5627                4.0          186.42
# 5628                9.0          178.90
# 5629                3.0          169.04
#
# [3774 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3774 entries, 0 to 5629
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Churn                        3774 non-null   int64
#  1   Tenure                       3774 non-null   float64
#  2   PreferredLoginDevice         3774 non-null   object
#  3   CityTier                     3774 non-null   int64
#  4   WarehouseToHome              3774 non-null   float64
#  5   PreferredPaymentMode         3774 non-null   object
#  6   Gender                       3774 non-null   object
#  7   HourSpendOnApp               3774 non-null   float64
#  8   NumberOfDeviceRegistered     3774 non-null   int64
#  9   PreferedOrderCat             3774 non-null   object
#  10  SatisfactionScore            3774 non-null   int64
#  11  MaritalStatus                3774 non-null   object
#  12  NumberOfAddress              3774 non-null   int64
#  13  Complain                     3774 non-null   int64
#  14  OrderAmountHikeFromlastYear  3774 non-null   float64
#  15  CouponUsed                   3774 non-null   float64
#  16  OrderCount                   3774 non-null   float64
#  17  DaySinceLastOrder            3774 non-null   float64
#  18  CashbackAmount               3774 non-null   float64
# dtypes: float64(8), int64(6), object(5)
# memory usage: 589.7+ KB

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

label_encodings = {}
for column in df.select_dtypes(include=['object']).columns:
    df[column] = label_encoder.fit_transform(df[column])
    label_encodings[column] = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))

label_encodings
# Out:
# {'PreferredLoginDevice': {'Computer': np.int64(0),
#   'Mobile Phone': np.int64(1),
#   'Phone': np.int64(2)},
#  'PreferredPaymentMode': {'CC': np.int64(0),
#   'COD': np.int64(1),
#   'Cash on Delivery': np.int64(2),
#   'Credit Card': np.int64(3),
#   'Debit Card': np.int64(4),
#   'E wallet': np.int64(5),
#   'UPI': np.int64(6)},
#  'Gender': {'Female': np.int64(0), 'Male': np.int64(1)},
#  'PreferedOrderCat': {'Fashion': np.int64(0),
#   'Grocery': np.int64(1),
#   'Laptop & Accessory': np.int64(2),
#   'Mobile': np.int64(3),
#   'Mobile Phone': np.int64(4),
#   'Others': np.int64(5)},
#  'MaritalStatus': {'Divorced': np.int64(0),
#   'Married': np.int64(1),
#   'Single': np.int64(2)}}

# %%
df
# Out:
#       Churn  Tenure  PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0         1     4.0                     1         3              6.0
# 3         1     0.0                     2         3             15.0
# 5         1     0.0                     0         1             22.0
# 11        1    11.0                     1         1              6.0
# 12        1     0.0                     2         1             11.0
# ...     ...     ...                   ...       ...              ...
# 5624      0     1.0                     1         3             12.0
# 5625      0    10.0                     0         1             30.0
# 5627      0     1.0                     1         1             11.0
# 5628      0    23.0                     0         3              9.0
# 5629      0     8.0                     1         1             15.0
#
#       PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0                        4       0             3.0                         3
# 3                        4       1             2.0                         4
# 5                        4       0             3.0                         5
# 11                       4       1             3.0                         4
# 12                       1       1             2.0                         3
# ...                    ...     ...             ...                       ...
# 5624                     6       0             2.0                         5
# 5625                     3       1             3.0                         2
# 5627                     4       1             3.0                         2
# 5628                     3       1             4.0                         5
# 5629                     3       1             3.0                         2
#
#       PreferedOrderCat  SatisfactionScore  MaritalStatus  NumberOfAddress  \
# 0                    2                  2              2                9
# 3                    2                  5              2                8
# 5                    4                  5              2                2
# 11                   0                  3              2               10
# 12                   3                  3              2                2
# ...                ...                ...            ...              ...
# 5624                 4                  3              2                2
# 5625                 2                  1              1                6
# 5627                 2                  4              1                3
# 5628                 2                  4              1                4
# 5629                 2                  3              1                4
#
#       Complain  OrderAmountHikeFromlastYear  CouponUsed  OrderCount  \
# 0            1                         11.0         1.0         1.0
# 3            0                         23.0         0.0         1.0
# 5            1                         22.0         4.0         6.0
# 11           1                         13.0         0.0         1.0
# 12           1                         13.0         2.0         2.0
# ...        ...                          ...         ...         ...
# 5624         0                         19.0         2.0         2.0
# 5625         0                         18.0         1.0         2.0
# 5627         1                         21.0         1.0         2.0
# 5628         0                         15.0         2.0         2.0
# 5629         0                         13.0         2.0         2.0
#
#       DaySinceLastOrder  CashbackAmount
# 0                   5.0          159.93
# 3                   3.0          134.07
# 5                   7.0          139.19
# 11                  0.0          153.81
# 12                  2.0          134.41
# ...                 ...             ...
# 5624                1.0          154.66
# 5625                4.0          150.71
# 5627                4.0          186.42
# 5628                9.0          178.90
# 5629                3.0          169.04
#
# [3774 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3774 entries, 0 to 5629
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Churn                        3774 non-null   int64
#  1   Tenure                       3774 non-null   float64
#  2   PreferredLoginDevice         3774 non-null   int64
#  3   CityTier                     3774 non-null   int64
#  4   WarehouseToHome              3774 non-null   float64
#  5   PreferredPaymentMode         3774 non-null   int64
#  6   Gender                       3774 non-null   int64
#  7   HourSpendOnApp               3774 non-null   float64
#  8   NumberOfDeviceRegistered     3774 non-null   int64
#  9   PreferedOrderCat             3774 non-null   int64
#  10  SatisfactionScore            3774 non-null   int64
#  11  MaritalStatus                3774 non-null   int64
#  12  NumberOfAddress              3774 non-null   int64
#  13  Complain                     3774 non-null   int64
#  14  OrderAmountHikeFromlastYear  3774 non-null   float64
#  15  CouponUsed                   3774 non-null   float64
#  16  OrderCount                   3774 non-null   float64
#  17  DaySinceLastOrder            3774 non-null   float64
#  18  CashbackAmount               3774 non-null   float64
# dtypes: float64(8), int64(11)
# memory usage: 589.7 KB

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
X = df.drop(columns=['Churn'])
y = df['Churn']
scaler = StandardScaler()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=33)
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

d_tree = DecisionTreeClassifier()
d_tree.fit(X_train_scaled, y_train)

y_pred = d_tree.predict(X_test_scaled)

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98       633
#            1       0.91      0.87      0.89       122
#
#     accuracy                           0.97       755
#    macro avg       0.94      0.93      0.94       755
# weighted avg       0.97      0.97      0.97       755

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

rf = RandomForestClassifier()
rf.fit(X_train_scaled, y_train)

y_pred = rf.predict(X_test_scaled)

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99       633
#            1       0.97      0.91      0.94       122
#
#     accuracy                           0.98       755
#    macro avg       0.98      0.95      0.96       755
# weighted avg       0.98      0.98      0.98       755

# %%
# Support Vector Machine (SVM)
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# Train SVM model
svm = SVC(probability=True)
svm.fit(X_train_scaled, y_train)

# Predict and evaluate
y_pred_svm = svm.predict(X_test_scaled)
report_svm = classification_report(y_test, y_pred_svm)
print("SVM Classification Report:")
print(report_svm)
# Out:
# SVM Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95       633
#            1       0.93      0.52      0.66       122
#
#     accuracy                           0.92       755
#    macro avg       0.92      0.75      0.81       755
# weighted avg       0.92      0.92      0.90       755

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report

nb = GaussianNB()
nb.fit(X_train_scaled, y_train)

y_pred_nb = nb.predict(X_test_scaled)
report_nb = classification_report(y_test, y_pred_nb)
print("Naive Bayes Classification Report:")
print(report_nb)
# Out:
# Naive Bayes Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93       633
#            1       0.65      0.52      0.58       122
#
#     accuracy                           0.88       755
#    macro avg       0.78      0.74      0.76       755
# weighted avg       0.87      0.88      0.87       755

# %%
import xgboost as xgb
from sklearn.metrics import classification_report

xgb_model = xgb.XGBClassifier(objective='binary:logistic', 
                             random_state=33,
                             n_estimators=100,
                             learning_rate=0.1)
xgb_model.fit(X_train_scaled, y_train)

y_pred_xgb = xgb_model.predict(X_test_scaled)
report_xgb = classification_report(y_test, y_pred_xgb)
print("XGBoost Classification Report:")
print(report_xgb)
# Out:
# XGBoost Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       633
#            1       0.96      0.80      0.88       122
#
#     accuracy                           0.96       755
#    macro avg       0.96      0.90      0.93       755
# weighted avg       0.96      0.96      0.96       755

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

log_reg = LogisticRegression(random_state=33, max_iter=1000)
log_reg.fit(X_train_scaled, y_train)

y_pred_log = log_reg.predict(X_test_scaled)
report_log = classification_report(y_test, y_pred_log)
print("Logistic Regression Classification Report:")
print(report_log)
# Out:
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94       633
#            1       0.80      0.48      0.60       122
#
#     accuracy                           0.90       755
#    macro avg       0.85      0.73      0.77       755
# weighted avg       0.89      0.90      0.89       755

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

models = ['Random Forest', 'SVM', 'Naive Bayes', 'XGBoost', 'Logistic Reg']
y_preds = [rf.predict(X_test_scaled), y_pred_svm, y_pred_nb, y_pred_xgb, y_pred_log]

accuracy_scores = [accuracy_score(y_test, pred) for pred in y_preds]
precision_scores = [precision_score(y_test, pred, average='weighted') for pred in y_preds]
recall_scores = [recall_score(y_test, pred, average='weighted') for pred in y_preds]
f1_scores = [f1_score(y_test, pred, average='weighted') for pred in y_preds]

metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
x = np.arange(len(metrics))
width = 0.15

fig, ax = plt.subplots(figsize=(12, 8))
rects1 = ax.bar(x - width*2, [accuracy_scores[0], precision_scores[0], recall_scores[0], f1_scores[0]], width, label='Random Forest')
rects2 = ax.bar(x - width, [accuracy_scores[1], precision_scores[1], recall_scores[1], f1_scores[1]], width, label='SVM')
rects3 = ax.bar(x, [accuracy_scores[2], precision_scores[2], recall_scores[2], f1_scores[2]], width, label='Naive Bayes')
rects4 = ax.bar(x + width, [accuracy_scores[3], precision_scores[3], recall_scores[3], f1_scores[3]], width, label='XGBoost')
rects5 = ax.bar(x + width*2, [accuracy_scores[4], precision_scores[4], recall_scores[4], f1_scores[4]], width, label='Logistic Reg')

ax.set_ylabel('Scores')
ax.set_title('Performance Metrics for Different Models')
ax.set_xticks(x)
ax.set_xticklabels(metrics)
ax.legend()

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height:.2f}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)
autolabel(rects3)
autolabel(rects4)
autolabel(rects5)

plt.ylim(0, 1.1)
plt.tight_layout()
plt.show()

# %%
from sklearn.neural_network import MLPClassifier

mlp = MLPClassifier(hidden_layer_sizes=(64, 64),  
                    activation='relu',          
                    solver='adam',               
                    max_iter=500,                
                    random_state=33)
mlp.fit(X_train_scaled, y_train)

y_pred = mlp.predict(X_test_scaled)

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98
50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9889 - loss: 0.0377 - val_accuracy: 0.9576 - val_loss: 0.2147
# Epoch 29/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9917 - loss: 0.0250 - val_accuracy: 0.9523 - val_loss: 0.2289
# Epoch 30/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9952 - loss: 0.0201 - val_accuracy: 0.9483 - val_loss: 0.2200
# Epoch 31/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9988 - loss: 0.0129 - val_accuracy: 0.9550 - val_loss: 0.2141
# Epoch 32/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9937 - loss: 0.0215 - val_accuracy: 0.9616 - val_loss: 0.2249
# Epoch 33/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9980 - loss: 0.0158 - val_accuracy: 0.9642 - val_loss: 0.1963
# Epoch 34/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9981 - loss: 0.0085 - val_accuracy: 0.9536 - val_loss: 0.2728
# Epoch 35/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9987 - loss: 0.0119 - val_accuracy: 0.9563 - val_loss: 0.2132
# Epoch 36/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9991 - loss: 0.0082 - val_accuracy: 0.9497 - val_loss: 0.2675
# Epoch 37/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9986 - loss: 0.0089 - val_accuracy: 0.9629 - val_loss: 0.2103
# Epoch 38/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9986 - loss: 0.0099 - val_accuracy: 0.9523 - val_loss: 0.2243
# Epoch 39/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9975 - loss: 0.0115 - val_accuracy: 0.9457 - val_loss: 0.3162
# Epoch 40/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9617 - loss: 0.0931 - val_accuracy: 0.9391 - val_loss: 0.2770
# Epoch 41/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9913 - loss: 0.0263 - val_accuracy: 0.9603 - val_loss: 0.2515
# Epoch 42/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9973 - loss: 0.0104 - val_accuracy: 0.9642 - val_loss: 0.2499
# Epoch 43/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9988 - loss: 0.0058 - val_accuracy: 0.9642 - val_loss: 0.2426
# Epoch 44/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9999 - loss: 0.0031 - val_accuracy: 0.9656 - val_loss: 0.2544
# Epoch 45/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9642 - val_loss: 0.2463
# Epoch 46/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9642 - val_loss: 0.2444
# Epoch 47/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.9642 - val_loss: 0.2451
# Epoch 48/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9629 - val_loss: 0.2503
# Epoch 49/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.9642 - val_loss: 0.2552
# Epoch 50/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9642 - val_loss: 0.2616

# %%
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

y_pred = model.predict(X_test_reshaped)
print(classification_report(y_test, y_pred>0.5))

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Model Accuracy')
plt.show()

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Model Loss')
plt.show()
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       633
#            1       0.94      0.84      0.88       122
#
#     accuracy                           0.96       755
#    macro avg       0.95      0.91      0.93       755
# weighted avg       0.96      0.96      0.96       755

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

X_train_reshaped = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_test_reshaped = X_test_scaled.reshape(X_test_scaled.shape[0], X_test_scaled.shape[1], 1)

model = Sequential()
model.add(LSTM(64, activation='relu', input_shape=(X_train_reshaped.shape[1], 1), return_sequences=True))
model.add(Dropout(0.2))  
model.add(LSTM(32, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# c:\Users\shaik\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train_reshaped, y_train, epochs=200, batch_size=32, validation_data=(X_test_reshaped, y_test))
# Out:
# Epoch 1/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.8216 - loss: 0.5551 - val_accuracy: 0.8384 - val_loss: 0.4219
# Epoch 2/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8454 - loss: 0.4228 - val_accuracy: 0.8384 - val_loss: 0.4128
# Epoch 3/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8225 - loss: 0.4361 - val_accuracy: 0.8384 - val_loss: 0.3669
# Epoch 4/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8174 - loss: 0.4074 - val_accuracy: 0.8384 - val_loss: 0.3409
# Epoch 5/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.8351 - loss: 0.3483 - val_accuracy: 0.8490 - val_loss: 0.3212
# Epoch 6/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.8595 - loss: 0.3270 - val_accuracy: 0.8689 - val_loss: 0.3144
# Epoch 7/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.
200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9744 - loss: 0.0546 - val_accuracy: 0.9338 - val_loss: 1.1559
# Epoch 195/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9797 - loss: 0.0598 - val_accuracy: 0.9364 - val_loss: 0.7125
# Epoch 196/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9707 - loss: 0.0639 - val_accuracy: 0.9417 - val_loss: 1.0503
# Epoch 197/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9822 - loss: 0.0550 - val_accuracy: 0.9086 - val_loss: 0.3032
# Epoch 198/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9278 - loss: 0.1849 - val_accuracy: 0.9258 - val_loss: 0.2326
# Epoch 199/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9545 - loss: 0.1107 - val_accuracy: 0.9430 - val_loss: 0.2484
# Epoch 200/200
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9751 - loss: 0.0708 - val_accuracy: 0.9351 - val_loss: 0.2749

# %%
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

y_pred = model.predict(X_test_reshaped)
print(classification_report(y_test, y_pred>0.5))

plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Test Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Model Accuracy')
plt.show()

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Model Loss')
plt.show()
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       633
#            1       0.83      0.75      0.79       122
#
#     accuracy                           0.94       755
#    macro avg       0.89      0.86      0.87       755
# weighted avg       0.93      0.94      0.93       755

# %% [markdown]
# Using CNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam

X_train_reshaped = X_train_scaled.reshape(X_train_scaled.shape[0], X_train_scaled.shape[1], 1)
X_test_reshaped = X_test_scaled.reshape(X_test_scaled.shape[0], X_test_scaled.shape[1], 1)

model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train_reshaped.shape[1], 1)))
model.add(MaxPooling1D(pool_size=2))  
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# c:\Users\shaik\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train_reshaped, y_train, epochs=50, batch_size=32, validation_data=(X_test_reshaped, y_test))
# Out:
# Epoch 1/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8144 - loss: 0.4841 - val_accuracy: 0.8424 - val_loss: 0.3840
# Epoch 2/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8409 - loss: 0.4004 - val_accuracy: 0.8649 - val_loss: 0.3457
# Epoch 3/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8527 - loss: 0.3649 - val_accuracy: 0.8861 - val_loss: 0.3096
# Epoch 4/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8677 - loss: 0.3337 - val_accuracy: 0.8901 - val_loss: 0.3046
# Epoch 5/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8840 - loss: 0.2777 - val_accuracy: 0.8755 - val_loss: 0.3089
# Epoch 6/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8997 - loss: 0.2634 - val_accuracy: 0.8914 - val_loss: 0.2672
# Epoch 7/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9088 - loss: 0.2336 - val_accuracy: 0.8901 - val_loss: 0.2684
# Epoch 8/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9025 - loss: 0.2396 - val_accuracy: 0.9099 - val_loss: 0.2323
# Epoch 9/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9199 - loss: 0.2028 - val_accuracy: 0.9033 - val_loss: 0.2397
# Epoch 10/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9227 - loss: 0.1886 - val_accuracy: 0.9086 - val_loss: 0.2230
# Epoch 11/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9256 - loss: 0.1888 - val_accuracy: 0.9126 - val_loss: 0.2375
# Epoch 12/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9330 - loss: 0.1669 - val_accuracy: 0.9219 - val_loss: 0.2164
# Epoch 13/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9428 - loss: 0.1562 - val_accuracy: 0.9073 - val_loss: 0.2385
# Epoch 14/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9413 - loss: 0.1420 - val_accuracy: 0.9152 - val_loss: 0.2107
# Epoch 15/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9377 - loss: 0.1379 - val_accuracy: 0.9298 - val_loss: 0.2012
# Epoch 16/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9561 - loss: 0.1148 - val_accuracy: 0.9126 - val_loss: 0.2449
# Epoch 17/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9547 - loss: 0.1216 - val_accuracy: 0.9351 - val_loss: 0.2110
# Epoch 18/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9661 - loss: 0.0938 - val_accuracy: 0.9417 - val_loss: 0.1940
# Epoch 19/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9662 - loss: 0.0910 - val_accuracy: 0.9338 - val_loss: 0.2376
# Epoch 20/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9732 - loss: 0.0733 - val_accuracy: 0.9272 - val_loss: 0.2151
# Epoch 21/50
# 95/95 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       633
#            1       0.93      0.86      0.89       122
#
#     accuracy                           0.97       755
#    macro avg       0.95      0.92      0.94       755
# weighted avg       0.97      0.97      0.97       755

# %%
import numpy as np
import pandas as pd

def encode_features(df):
    """
    Encodes the categorical columns in the provided dataframe based on the predefined label encodings.
    """
    label_encodings = {
        'PreferredLoginDevice': {'Computer': 0, 'Mobile Phone': 1, 'Phone': 2},
        'PreferredPaymentMode': {
            'CC': 0, 'COD': 1, 'Cash on Delivery': 2, 'Credit Card': 3, 
            'Debit Card': 4, 'E wallet': 5, 'UPI': 6
        },
        'Gender': {'Female': 0, 'Male': 1},
        'PreferedOrderCat': {
            'Fashion': 0, 'Grocery': 1, 'Laptop & Accessory': 2, 'Mobile': 3, 
            'Mobile Phone': 4, 'Others': 5
        },
        'MaritalStatus': {'Divorced': 0, 'Married': 1, 'Single': 2}
    }

    for column, encoding in label_encodings.items():
        if column in df.columns:
            df[column] = df[column].map(encoding)
    
    return df

# %%
def predict_churn(model, data):

    if isinstance(data, dict):
        data = pd.DataFrame([data])
    
    required_columns = ['Tenure', 'PreferredLoginDevice', 'CityTier', 'WarehouseToHome', 
                        'PreferredPaymentMode', 'Gender', 'HourSpendOnApp', 'NumberOfDeviceRegistered', 
                        'PreferedOrderCat', 'SatisfactionScore', 'MaritalStatus', 'NumberOfAddress', 
                        'Complain', 'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount', 
                        'DaySinceLastOrder', 'CashbackAmount']
    
    missing_cols = set(required_columns) - set(data.columns)
    if missing_cols:
        raise ValueError(f"Missing columns: {missing_cols}")
    
    data = encode_features(data)
    data = data.to_numpy()
    data = scaler.transform(data)
    data = data.reshape(data.shape[0], data.shape[1], 1)
    
    prediction = model.predict(data)
    churn_probability = prediction[0][0] 
    months_to_churn = (1 - churn_probability) * 24 +1
    return int(months_to_churn)

# %%
input_data = {
    'Tenure': 1.0,
    'PreferredLoginDevice': 'Mobile Phone',
    'CityTier': 3,
    'WarehouseToHome': 12.0,
    'PreferredPaymentMode': 'UPI',
    'Gender': 'Female',
    'HourSpendOnApp': 2.0,
    'NumberOfDeviceRegistered': 5,
    'PreferedOrderCat': 'Mobile Phone',
    'SatisfactionScore': 3,
    'MaritalStatus': 'Single',
    'NumberOfAddress': 2,
    'Complain': 0,
    'OrderAmountHikeFromlastYear': 19,
    'CouponUsed': 2.0,
    'OrderCount': 2.0,
    'DaySinceLastOrder': 1.0,
    'CashbackAmount': 154.66
}

churn_prediction = predict_churn(model, input_data)
print(f"Customer may leave in: {churn_prediction} month(s)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Customer may leave in: 24 month(s)
# c:\Users\shaik\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
input_data = {
    'Tenure': 4.0,
    'PreferredLoginDevice': 'Mobile Phone',
    'CityTier': 3,
    'WarehouseToHome': 6.0,
    'PreferredPaymentMode': 'Debit Card',
    'Gender': 'Female',
    'HourSpendOnApp': 3.0,
    'NumberOfDeviceRegistered': 3,
    'PreferedOrderCat': 'Laptop & Accessory',
    'SatisfactionScore': 2,
    'MaritalStatus': 'Single',
    'NumberOfAddress': 9,
    'Complain': 1,
    'OrderAmountHikeFromlastYear': 11.0,
    'CouponUsed': 1,
    'OrderCount': 1,
    'DaySinceLastOrder': 5,
    'CashbackAmount': 159.93
}

churn_prediction = predict_churn(model, input_data)
print(f"Customer may leave in: {churn_prediction} month(s)")
# Out:
# c:\Users\shaik\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Customer may leave in: 1 month(s)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report
import shap
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[35], line 11
#       9 from tensorflow.keras.optimizers import Adam
#      10 from sklearn.metrics import classification_report
# ---> 11 import shap
#
# ModuleNotFoundError: No module named 'shap'

# %%
file_path = "E_Commerce_Dataset.xlsx"
xls = pd.ExcelFile(file_path)
df = pd.read_excel(xls, sheet_name="E Comm")

# %%
df.fillna(df.median(numeric_only=True), inplace=True)
df_encoded = pd.get_dummies(df.drop(columns=['CustomerID']), drop_first=True)
X = df_encoded.drop(columns=['Churn'])
y = df_encoded['Churn']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=33)
X_train_reshaped = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test_reshaped = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train_reshaped.shape[1], 1)))
model.add(MaxPooling1D(pool_size=2))  
model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid')) 
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

history = model.fit(X_train_reshaped, y_train, epochs=50, batch_size=32, validation_data=(X_test_reshaped, y_test))
# Out:
# Epoch 1/50
# c:\Users\dipen\OneDrive\Desktop\Qriocity\venv\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8287 - loss: 0.4382 - val_accuracy: 0.8508 - val_loss: 0.3734
# Epoch 2/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8519 - loss: 0.3572 - val_accuracy: 0.8703 - val_loss: 0.3366
# Epoch 3/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8724 - loss: 0.3197 - val_accuracy: 0.8819 - val_loss: 0.3059
# Epoch 4/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8758 - loss: 0.2931 - val_accuracy: 0.8739 - val_loss: 0.3150
# Epoch 5/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8912 - loss: 0.2746 - val_accuracy: 0.8899 - val_loss: 0.3049
# Epoch 6/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9054 - loss: 0.2501 - val_accuracy: 0.8899 - val_loss: 0.2942
# Epoch 7/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8987 - loss: 0.2439 - val_accuracy: 0.8961 - val_loss: 0.2626
# Epoch 8/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9151 - loss: 0.2281 - val_accuracy: 0.8925 - val_loss: 0.2563
# Epoch 9/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9096 - loss: 0.2191 - val_accuracy: 0.8810 - val_loss: 0.3313
# Epoch 10/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9139 - loss: 0.2154 - val_accuracy: 0.8961 - val_loss: 0.2467
# Epoch 11/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9224 - loss: 0.1924 - val_accuracy: 0.8917 - val_loss: 0.2561
# Epoch 12/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9250 - loss: 0.1817 - val_accuracy: 0.9112 - val_loss: 0.2299
# Epoch 13/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9269 - loss: 0.1766 - val_accuracy: 0.9076 - val_loss: 0.2252
# Epoch 14/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9335 - loss: 0.1670 - val_accuracy: 0.9147 - val_loss: 0.2223
# Epoch 15/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9360 - loss: 0.1579 - val_accuracy: 0.9210 - val_loss: 0.2057
# Epoch 16/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9424 - loss: 0.1396 - val_accuracy: 0.9112 - val_loss: 0.2752
# Epoch 17/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9475 - loss: 0.1315 - val_accuracy: 0.9183 - val_loss: 0.2011
# Epoch 18/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9575 - loss: 0.1171 - val_accuracy: 0.9218 - val_loss: 0.2143
# Epoch 19/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9592 - loss: 0.1087 - val_accuracy: 0.9218 - val_loss: 0.1968
# Epoch 20/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9635 - loss: 0.0993 - val_accuracy: 0.9218 - val_loss: 0.2110
# Epoch 21/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9619 - loss: 0.1029 - val_accuracy: 0.9254 - val_loss: 0.1894
# Epoch 22/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9657 - loss: 0.0922 - val_accuracy: 0.9307 - val_loss: 0.1877
# Epoch 23/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9660 - loss: 0.0951 - val_accuracy: 0.9290 - val_loss: 0.2007
# Epoch 24/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9708 - loss: 0.0792 - val_accuracy: 0.9352 - val_loss: 0.1886
# Epoch 25/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9643 - loss: 0.0805 - val_accuracy: 0.9316 - val_loss: 0.1892
# Epoch 26/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9808 - loss: 0.0592 - val_accuracy: 0.9334 - val_loss: 0.1868
# Epoch 27/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9838 - loss: 0.0507 - val_accuracy: 0.9369 - val_loss: 0.1961
# Epoch 28/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9815 - loss: 0.0503 - val_accuracy: 0.9369 - val_loss: 0.2154
# Epoch 29/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9817 - loss: 0.0487 - val_accuracy: 0.9272 - val_loss: 0.2101
# Epoch 30/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9807 - loss: 0.0533 - val_accuracy: 0.9387 - val_loss: 0.1789
# Epoch 31/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9842 - loss: 0.0428 - val_accuracy: 0.9423 - val_loss: 0.1827
# Epoch 32/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9935 - loss: 0.0257 - val_accuracy: 0.9414 - val_loss: 0.1751
# Epoch 33/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9881 - loss: 0.0369 - val_accuracy: 0.9334 - val_loss: 0.2593
# Epoch 34/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9901 - loss: 0.0294 - val_accuracy: 0.9414 - val_loss: 0.1896
# Epoch 35/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9929 - loss: 0.0240 - val_accuracy: 0.9432 - val_loss: 0.2076
# Epoch 36/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9961 - loss: 0.0197 - val_accuracy: 0.9565 - val_loss: 0.2000
# Epoch 37/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9966 - loss: 0.0184 - val_accuracy: 0.9378 - val_loss: 0.2579
# Epoch 38/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9889 - loss: 0.0324 - val_accuracy: 0.9458 - val_loss: 0.2051
# Epoch 39/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9871 - loss: 0.0375 - val_accuracy: 0.9458 - val_loss: 0.2119
# Epoch 40/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9892 - loss: 0.0287 - val_accuracy: 0.9512 - val_loss: 0.2053
# Epoch 41/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9958 - loss: 0.0156 - val_accuracy: 0.9529 - val_loss: 0.1751
# Epoch 42/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9995 - loss: 0.0066 - val_accuracy: 0.9485 - val_loss: 0.2362
# Epoch 43/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9999 - loss: 0.0060 - val_accuracy: 0.9494 - val_loss: 0.1908
# Epoch 44/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9999 - loss: 0.0056 - val_accuracy: 0.9556 - val_loss: 0.1966
# Epoch 45/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9998 - loss: 0.0047 - val_accuracy: 0.9583 - val_loss: 0.1945
# Epoch 46/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9999 - loss: 0.0039 - val_accuracy: 0.9538 - val_loss: 0.2103
# Epoch 47/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9547 - val_loss: 0.2175
# Epoch 48/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9565 - val_loss: 0.2123
# Epoch 49/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9556 - val_loss: 0.2092
# Epoch 50/50
# 141/141 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9661 - loss: 0.0976 - val_accuracy: 0.9307 - val_loss: 0.2467

# %%
background = X_train_reshaped[np.random.choice(X_train_reshaped.shape[0], 100, replace=False)]
explainer = shap.GradientExplainer(model, background)
shap_values = explainer.shap_values(X_test_reshaped[:100])
shap_values = np.array(shap_values).squeeze()  
shap_importance = np.mean(np.abs(shap_values), axis=0)  
if shap_importance.shape[0] != X.shape[1]:
    shap_importance = shap_importance[:X.shape[1]]
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': shap_importance})
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)
print("Feature Importance (SHAP-based):")
print(feature_importance_df.head(10))
# Out:
# c:\Users\dipen\OneDrive\Desktop\Qriocity\venv\lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_218
# Received: inputs=['Tensor(shape=(100, 29, 1))']
#   warnings.warn(msg)
# c:\Users\dipen\OneDrive\Desktop\Qriocity\venv\lib\site-packages\keras\src\models\functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_218
# Received: inputs=['Tensor(shape=(50, 29, 1))']
#   warnings.warn(msg)
# Feature Importance (SHAP-based):
#                                 Feature  Importance
# 0                                Tenure    0.121699
# 11                    DaySinceLastOrder    0.063510
# 5                     SatisfactionScore    0.058916
# 7                              Complain    0.056888
# 2                       WarehouseToHome    0.052858
# 12                       CashbackAmount    0.050311
# 23  PreferedOrderCat_Laptop & Accessory    0.049613
# 6                       NumberOfAddress    0.047276
# 19        PreferredPaymentMode_E wallet    0.047198
# 4              NumberOfDeviceRegistered    0.042733

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=feature_importance_df['Importance'], y=feature_importance_df['Feature'], palette="viridis")
plt.title("SHAP Feature Importance")
plt.xlabel("Mean Absolute SHAP Value")
plt.ylabel("Feature")
plt.show()
# Out:
# C:\Users\dipen\AppData\Local\Temp\ipykernel_10432\356697167.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=feature_importance_df['Importance'], y=feature_importance_df['Feature'], palette="viridis")

# %%
y_pred = (model.predict(X_test_reshaped) > 0.5).astype("int32")
classification_rep = classification_report(y_test, y_pred, output_dict=True)
classification_df = pd.DataFrame(classification_rep).transpose()
print("\nClassification Report:")
print(classification_df)
# Out:
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# Classification Report:
#               precision    recall  f1-score      support
# 0              0.945777  0.972133  0.958774   933.000000
# 1              0.844311  0.730570  0.783333   193.000000
# accuracy       0.930728  0.930728  0.930728     0.930728
# macro avg      0.895044  0.851351  0.871054  1126.000000
# weighted avg   0.928385  0.930728  0.928703  1126.000000

# %%
gender_churn = df.groupby('Gender')['Churn'].mean() * 100
plt.figure(figsize=(8, 5))
sns.barplot(x=gender_churn.index, y=gender_churn.values, palette="coolwarm")
plt.title('Percentage of Churn by Gender')
plt.ylabel('Churn Percentage (%)')
plt.xlabel('Gender')
plt.show()
# Out:
# C:\Users\dipen\AppData\Local\Temp\ipykernel_10432\358250411.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=gender_churn.index, y=gender_churn.values, palette="coolwarm")

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Tenure'], bins=20, kde=True, color='blue')
plt.title('Distribution of Customer Tenure')
plt.xlabel('Tenure (months)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Churn'], y=df['HourSpendOnApp'])
plt.title('App Usage Hours vs Churn')
plt.xlabel('Churn')
plt.ylabel('Hours Spent on App')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Churn'], y=df['CouponUsed'])
plt.title('Coupon Usage vs Churn')
plt.xlabel('Churn')
plt.ylabel('Coupons Used')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Churn'], y=df['SatisfactionScore'])
plt.title('Satisfaction Score vs Churn')
plt.xlabel('Churn')
plt.ylabel('Satisfaction Score')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Churn'], y=df['Complain'])
plt.title('Customer Complaints vs Churn')
plt.xlabel('Churn')
plt.ylabel('Number of Complaints')
plt.show()
